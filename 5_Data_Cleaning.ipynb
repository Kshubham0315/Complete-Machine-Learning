# %% [markdown]
#     Total 40 concepts is there

# %% [markdown]
#     1. Remove Duplicate Data

# %%
import pandas as pd

# %%
# check is duplicate or not 
# let df be any frame 

data = {'Name': ['Alice', 'Bob', 'Alice', 'Charlie'], 'Age': [25, 
30, 25, 35]} 

df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2    Alice   25
# 3  Charlie   35

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 3  Charlie   35

# %% [markdown]
#     2. Handle Missing Values

# %%
data = {'Name': ['Alice', 'Bob', None, 'Charlie'], 'Age': [25, 
None, 30, 35]} 
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name   Age
# 0    Alice  25.0
# 1      Bob   NaN
# 2     None  30.0
# 3  Charlie  35.0

# %%
df.isnull().sum()
# Out:
# Name    1
# Age     1
# dtype: int64

# %%
# fill karna pade 
df.fillna({'Name':'Rajesh' , 'Age':df['Age'].mean()})
# Out:
#       Name   Age
# 0    Alice  25.0
# 1      Bob  30.0
# 2   Rajesh  30.0
# 3  Charlie  35.0

# %% [markdown]
#     3. Correct Data Types

# %%
data = {'Date': ['2023-01-01', '2023-02-01', '2023-03-01'], 
'Product': ['Product A', 'Product B', 'Product C'], 
'Sales': [100, 150, 200]}
df = pd.DataFrame(data)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Date       datetime64[ns]
# Product            object
# Sales               int64
# dtype: object

# %% [markdown]
#     4. Standardize Data

# %%
data = {'Name': ['alice', 'BOB', 'Charlie'], 'Age': [25, 
30, 35]} 
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age
# 0    alice   25
# 1      BOB   30
# 2  Charlie   35

# %%
df['Name'] = df['Name'].str.title()

# %%
df
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %% [markdown]
#     5. Filter Outliers

# %%
# box plot mainly used to check the outliers of the data

# Sample data with outliers 
data = {'Values': [10, 12, 1000, 13]} 
df = pd.DataFrame(data) 
print("Original DataFrame") 
display(df) 

# Calculate IQR 
Q1 = df['Values'].quantile(0.25) 
Q3 = df['Values'].quantile(0.75) 
IQR = Q3 - Q1 

# Define outlier bounds     
lower_bound = Q1 - 1.5 * IQR 
upper_bound = Q3 + 1.5 * IQR 
# Filter out outliers 
df_cleaned = df[(df['Values'] >= lower_bound) & (df['Values'] <= 
upper_bound)] 
print("\033[32mCleaned DataFrame\033[0m") 
display(df_cleaned)
# Out:
# Original DataFrame
#    Values
# 0      10
# 1      12
# 2    1000
# 3      13
# Cleaned DataFrame
#    Values
# 0      10
# 1      12
# 3      13

# %%
import matplotlib.pyplot as plt

df.boxplot(column='Values')
# Out:
# <Axes: >

# %% [markdown]
#     6. Normalize Data

# %%
# yeh simple apna sklearn se ho jata hai 

from sklearn.preprocessing import MinMaxScaler

sclaer = MinMaxScaler()

sclaer.fit_transform(X_train)

# %% [markdown]
#     7. Remove Irrelevant Data

# %%
data = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 
30, 35], 'Unnecessary': [1, 2, 3]} 
df = pd.DataFrame(data)

# %%
df.drop(columns=["Unnecessary"])
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %% [markdown]
#     8. Validate Data Integrity
