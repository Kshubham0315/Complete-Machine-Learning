# %% [markdown]
# # Handling Mixed Values

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#   Cabin            Ticket number  Survived
# 0   NaN         A/5 21171      5         0
# 1   C85          PC 17599      3         1
# 2   NaN  STON/O2. 3101282      6         1
# 3  C123            113803      3         1
# 4   NaN            373450      A         0

# %%
df['number'].unique()
# Out:
# array(['5', '3', '6', 'A', '2', '1', '4'], dtype=object)

# %%
fig = df['number'].value_counts().plot.bar() #pandas ke through
fig.set_title('Passengers travelling with')
# Out:
# Text(0.5, 1.0, 'Passengers travelling with')

# %%
# extract numerical part
df['number_numerical'] = pd.to_numeric(df["number"],errors='coerce',downcast='integer')

# %%
df['number_numerical'].head(2)
# Out:
# 0    5.0
# 1    3.0
# Name: number_numerical, dtype: float64

# %%
# extract categorical part
df['number_categorical'] = np.where(df['number_numerical'].isnull(),df['number'],np.nan)

# %%
df['number_categorical'].head(2)
# Out:
# 0    NaN
# 1    NaN
# Name: number_categorical, dtype: object

# %%
df.head()
# Out:
#   Cabin            Ticket number  Survived  number_numerical  \
# 0   NaN         A/5 21171      5         0               5.0
# 1   C85          PC 17599      3         1               3.0
# 2   NaN  STON/O2. 3101282      6         1               6.0
# 3  C123            113803      3         1               3.0
# 4   NaN            373450      A         0               NaN
#
#   number_categorical
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                  A

# %% [markdown]
# abhi tak toh simply humne sirf numeric part or categorical part ko alag alag kiya hai bas

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df['Ticket'].unique()
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295', 'A/4. 39886', 'PC 17572', '2926',
#        '113509', '19947', 'C.A. 31026', '2697', 'C.A. 34651', 'CA 2144',
#        '2669', '113572', '36973', '347088', 'PC 17605', '2661',
#        'C.A. 29395', 'S.P. 3464', '3101281', '315151', 'C.A. 33111',
#        'S.O.C. 14879', '2680', '1601', '348123', '349208', '374746',
# ...

# %%
df['cabin_num'] = df['Cabin'].str.extract('(\d+)') # captures numerical part
df['cabin_cat'] = df['Cabin'].str[0] # captures the first letter

df.head()
# Out:
#   Cabin            Ticket number  Survived  number_numerical  \
# 0   NaN         A/5 21171      5         0               5.0
# 1   C85          PC 17599      3         1               3.0
# 2   NaN  STON/O2. 3101282      6         1               6.0
# 3  C123            113803      3         1               3.0
# 4   NaN            373450      A         0               NaN
#
#   number_categorical cabin_num cabin_cat
# 0                NaN       NaN       NaN
# 1                NaN        85         C
# 2                NaN       NaN       NaN
# 3                NaN       123         C
# 4                  A       NaN       NaN

# %% [markdown]
# simply yaha tak humne sirf dono ko alg alg kar diya hai

# %%
df['cabin_cat'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='cabin_cat'>

# %%
df['ticket_num'] = df['Ticket'].apply(lambda s : s.split()[-1])
# basically jaha bhi space milega vahi se yeh split mardega then last part numeric hai usko le lega

df['ticket_num'] = pd.to_numeric(df['ticket_num'],errors='coerce',downcast='integer')

# %%
df['ticket_num'].head(2)
# Out:
# 0    21171.0
# 1    17599.0
# Name: ticket_num, dtype: float64

# %%
df['ticket_cat'] = df['Ticket'].apply(lambda s: s.split()[0])
df['ticket_cat'] = np.where(df['ticket_cat'].str.isdigit(), np.nan,df['ticket_cat'])

# %%
df.head(20)
# Out:
#    Cabin            Ticket number  Survived  number_numerical  \
# 0    NaN         A/5 21171      5         0               5.0
# 1    C85          PC 17599      3         1               3.0
# 2    NaN  STON/O2. 3101282      6         1               6.0
# 3   C123            113803      3         1               3.0
# 4    NaN            373450      A         0               NaN
# 5    NaN            330877      2         0               2.0
# 6    E46             17463      2         0               2.0
# 7    NaN            349909      5         0               5.0
# 8    NaN            347742      1         1               1.0
# 9    NaN            237736      A         1               NaN
# 10    G6           PP 9549      1         1               1.0
# 11  C103            113783      1         1               1.0
# 12   NaN         A/5. 2151      3         0               3.0
# 13   NaN            347082      3         0               3.0
# ...

# %% [markdown]
# simple yaha tak humne ticket vale column ko split kar diya hai...

# %%
df['ticket_cat'].unique()
# Out:
# array(['A/5', 'PC', 'STON/O2.', nan, 'PP', 'A/5.', 'C.A.', 'A./5.',
#        'SC/Paris', 'S.C./A.4.', 'A/4.', 'CA', 'S.P.', 'S.O.C.', 'SO/C',
#        'W./C.', 'SOTON/OQ', 'W.E.P.', 'STON/O', 'A4.', 'C', 'SOTON/O.Q.',
#        'SC/PARIS', 'S.O.P.', 'A.5.', 'Fa', 'CA.', 'LINE', 'F.C.C.', 'W/C',
#        'SW/PP', 'SCO/W', 'P/PP', 'SC', 'SC/AH', 'A/S', 'A/4', 'WE/P',
#        'S.W./PP', 'S.O./P.P.', 'F.C.', 'SOTON/O2', 'S.C./PARIS',
#        'C.A./SOTON'], dtype=object)

# %% [markdown]
# # Handling date and time

# %%
import numpy as np
import pandas as pd

# %%
date = pd.read_csv('Desktop/CampusX-ML/orders.csv')
time = pd.read_csv('Desktop/CampusX-ML/messages.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 date = pd.read_csv('Desktop/CampusX-ML/orders.csv')
#       2 time = pd.read_csv('Desktop/CampusX-ML/messages.csv')
#
# ...

# %% [markdown]
# 2019-05-04 --
#
# date['date_year'] = date['date'].dt.year
#
# date['date_month_no'] = date['date'].dt.month
#
# date['date_month_name'] = date['date'].dt.month_name()
#
# date['date_day'] = date['date'].dt.day
#
# date['date_dow'] = date['date'].dt.dayofweek
#
# date['date_dow_name'] = date['date'].dt.day_name()

# %% [markdown]
# # Handling Missing Data

# %% [markdown]
# Methods of treting missing values : -
#
# 1. Drop the row
#
# 2. Fill that missing value
#
#  -- Univariate/Bivariate -- numerical (mean , median , random) , catergorical (mode)
#
#  -- Multivariate -- knn imputer + iterative imputer -- sklearn

# %% [markdown]
# # Deleting the row the missing values in the dataset

# %%
# iska use jab less than 5% data ke kam miss ho tabhi iska use karte hai varna nahi karte hai imputer pe focus karte hai 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cols = [var for var in df.columns if df[var].isnull().mean()*100 < 0.05 and df[var].isnull().mean() > 0]
# now you got the columns in array formate

# %% [markdown]
# # Statstical method to fill the missing values

# %% [markdown]
# from sklearn.model_selection import train_test_split
# from sklearn.impute import SimpleImputer
# from sklearn.compose import ColumnTransformer

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv('titanic_toy.csv')

# %%
df.head()
# Out:
#     Age     Fare  Family  Survived
# 0  22.0   7.2500       1         0
# 1  38.0  71.2833       1         1
# 2  26.0   7.9250       0         1
# 3  35.0  53.1000       1         1
# 4  35.0   8.0500       0         0

# %%
df.isnull().mean()
# Out:
# Age         0.198653
# Fare        0.050505
# Family      0.000000
# Survived    0.000000
# dtype: float64

# %%
X = df.drop(columns=['Survived'])
y = df['Survived']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train.shape, X_test.shape
# Out:
# ((712, 3), (179, 3))

# %%
X_train.isnull().mean()
# Out:
# Age       0.207865
# Fare      0.050562
# Family    0.000000
# dtype: float64

# %%
mean_age = X_train['Age'].mean()
median_age = X_train['Age'].median()

mean_fare = X_train['Fare'].mean()
median_fare = X_train['Fare'].median()

# %%
X_train['Age_median'] = X_train['Age'].fillna(median_age)
X_train['Age_mean'] = X_train['Age'].fillna(mean_age)

X_train['Fare_median'] = X_train['Fare'].fillna(median_fare)
X_train['Fare_mean'] = X_train['Fare'].fillna(mean_fare)

# %%
X_train.sample(5)
# Out:
#       Age     Fare  Family  Age_median   Age_mean  Fare_median  Fare_mean
# 691   4.0  13.4167       1        4.00   4.000000      13.4167    13.4167
# 328  31.0  20.5250       2       31.00  31.000000      20.5250    20.5250
# 460  48.0  26.5500       0       48.00  48.000000      26.5500    26.5500
# 320  22.0   7.2500       0       22.00  22.000000       7.2500     7.2500
# 727   NaN   7.7375       0       28.75  29.785904       7.7375     7.7375

# %% [markdown]
# mean median lagane se variance humesa shrink kar jata hai

# %%
print('Original Age variable variance: ', X_train['Age'].var())
print('Age Variance after median imputation: ', X_train['Age_median'].var())
print('Age Variance after mean imputation: ', X_train['Age_mean'].var())

print('Original Fare variable variance: ', X_train['Fare'].var())
print('Fare Variance after median imputation: ', X_train['Fare_median'].var())
print('Fare Variance after mean imputation: ', X_train['Fare_mean'].var())
# Out:
# Original Age variable variance:  204.3495133904614
# Age Variance after median imputation:  161.9895663346054
# Age Variance after mean imputation:  161.81262452718673
# Original Fare variable variance:  2448.197913706318
# Fare Variance after median imputation:  2340.0910219753637
# Fare Variance after mean imputation:  2324.2385256705547

# %% [markdown]
# Shrinkiness yaha pe dekh sakteho

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original variable distribution
X_train['Age'].plot(kind='kde', ax=ax)

# variable imputed with the median
X_train['Age_median'].plot(kind='kde', ax=ax, color='red')

# variable imputed with the mean
X_train['Age_mean'].plot(kind='kde', ax=ax, color='green')

# add legends
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original variable distribution
X_train['Fare'].plot(kind='kde', ax=ax)

# variable imputed with the median
X_train['Fare_median'].plot(kind='kde', ax=ax, color='red')

# variable imputed with the mean
X_train['Fare_mean'].plot(kind='kde', ax=ax, color='green')

# add legends
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

# %%
X_train.cov()
# Out:
#                     Age         Fare     Family  Age_median    Age_mean  \
# Age          204.349513    70.719262  -6.498901  204.349513  204.349513
# Fare          70.719262  2448.197914  17.258917   57.957599   55.603719
# Family        -6.498901    17.258917   2.735252   -5.112563   -5.146106
# Age_median   204.349513    57.957599  -5.112563  161.989566  161.812625
# Age_mean     204.349513    55.603719  -5.146106  161.812625  161.812625
# Fare_median   64.858859  2448.197914  16.476305   53.553455   51.358000
# Fare_mean     66.665205  2448.197914  16.385048   55.023037   52.788341
#
#              Fare_median    Fare_mean
# Age            64.858859    66.665205
# Fare         2448.197914  2448.197914
# Family         16.476305    16.385048
# Age_median     53.553455    55.023037
# Age_mean       51.358000    52.788341
# Fare_median  2340.091022  2324.238526
# Fare_mean    2324.238526  2324.238526

# %%
X_train.corr()
# Out:
#                   Age      Fare    Family  Age_median  Age_mean  Fare_median  \
# Age          1.000000  0.092644 -0.299113    1.000000  1.000000     0.087356
# Fare         0.092644  1.000000  0.208268    0.091757  0.088069     1.000000
# Family      -0.299113  0.208268  1.000000   -0.242883 -0.244610     0.205942
# Age_median   1.000000  0.091757 -0.242883    1.000000  0.999454     0.086982
# Age_mean     1.000000  0.088069 -0.244610    0.999454  1.000000     0.083461
# Fare_median  0.087356  1.000000  0.205942    0.086982  0.083461     1.000000
# Fare_mean    0.090156  1.000000  0.205499    0.089673  0.086078     0.996607
#
#              Fare_mean
# Age           0.090156
# Fare          1.000000
# Family        0.205499
# Age_median    0.089673
# Age_mean      0.086078
# Fare_median   0.996607
# Fare_mean     1.000000

# %%
X_train[['Age', 'Age_median', 'Age_mean']].boxplot()
# Out:
# <Axes: >

# %%
X_train[['Fare', 'Fare_median', 'Fare_mean']].boxplot()
# Out:
# <Axes: >
